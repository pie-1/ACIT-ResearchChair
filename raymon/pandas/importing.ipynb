# %% [markdown]
# CSV = Comma-seperated values.
#
# JSON = JavaScript Object Notation

# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon.csv")            #We are creating a dataframe with the
#                                         the csv file.

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Quick warning: Printing entire 800 row dataset will flood the terminal.
# Thats why the above displayed dataset is a trunketed version.
#
# To show up to 100 rows instead of all 800:
#
#         pd.set_option('display.max_rows', 100)

# %% [markdown]
# For reading a json files:

# %%
prototype_df = pd.read_json("demo.json")

# %%
print(prototype_df.to_string())
# Out:
#       name  grade                 stream                                           strengths                       extracurriculars                             role
# 0   Anjali     11          Science (PCM)       [Calculus, Analytical Writing, Coding Basics]  [Debate Club, Classical Dance, Chess]  Vice-President of the STEM Club
# 1   Raymon     11  Management / Commerce        [Financial Accounting, Economics, Marketing]     [Basketball (Forward), Drama Club]          Sports Meet Coordinator
# 2  Shubham     11  Computer Science / IT  [Python Programming, Hardware Systems, Statistics]     [Robotics Club, Gaming, Quiz Team]           Tech Support Volunteer
